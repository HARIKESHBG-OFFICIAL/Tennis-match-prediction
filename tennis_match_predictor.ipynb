# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
atp = pd.read_csv('atp_tennis.csv')

df = pd.DataFrame(atp)

df['player1_win'] = (df['Winner'] == df['Player_1']).astype(int)


encoded_df = pd.get_dummies(df[['Tournament','Series','Surface','Round','Player_1','Player_2']], dtype='float')

df['Winner'].value_counts()

df['Court'] = df['Court'].map({'Indoor': 0, 'Outdoor': 1})

numeric_df = df[['Court','Best of','Rank_1','Rank_2','Pts_1','Pts_2','Odd_1','Odd_2']]


df['Date'] = pd.to_datetime(df['Date'])

df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df['day'] = df['Date'].dt.day

date_df=df[['year','month','day']]

# %%
def get_score_features(score):
    if not score or pd.isna(score):
        return {'won': 0, 'lost': 0, 'sets': 0, 'diff': 0}

    parts = score.split()
    won = 0
    lost = 0
    for p in parts:
        try:
            w, l = map(int, p.split('-'))
            won += w
            lost += l
        except:
            pass
    sets = len(parts)
    diff = abs(won - lost)
    return {'won': won, 'lost': lost, 'sets': sets, 'diff': diff}

features_df = df['Score'].apply(get_score_features).apply(pd.Series)
X=pd.concat([numeric_df,encoded_df,date_df,features_df],axis=1)

# %%
y=df['player1_win']
X_train,X_test,y_train,y_test= train_test_split(X , y , test_size=0.2)

rfmodel = RandomForestClassifier(n_estimators=100,max_depth=12, random_state=42)

rfmodel.fit(X_train , y_train)
prediction=rfmodel.predict(X_test)

accuracy=accuracy_score(y_test,prediction)
print(f"The accuracy %  = {accuracy}")
# Out:
# The accuracy %  = 0.8650371147934318

# %%
df
# Out:
#                                Tournament       Date         Series  Court  \
# 0      Australian Hardcourt Championships 2000-01-03  International      1
# 1      Australian Hardcourt Championships 2000-01-03  International      1
# 2      Australian Hardcourt Championships 2000-01-03  International      1
# 3      Australian Hardcourt Championships 2000-01-03  International      1
# 4      Australian Hardcourt Championships 2000-01-03  International      1
# ...                                   ...        ...            ...    ...
# 66676                         Masters Cup 2025-11-14    Masters Cup      0
# 66677                         Masters Cup 2025-11-14    Masters Cup      0
# 66678                         Masters Cup 2025-11-15    Masters Cup      0
# 66679                         Masters Cup 2025-11-15    Masters Cup      0
# 66680                         Masters Cup 2025-11-16    Masters Cup      0
#
#       Surface        Round  Best of            Player_1            Player_2  \
# 0        Hard    1st Round        3          Dosedel S.         Ljubicic I.
# 1        Hard    1st Round        3          Clement A.          Enqvist T.
# 2        Hard    1st Round        3           Escude N.       Baccanello P.
# 3        Hard    1st Round        3      Knippschild J.          Federer R.
# 4        Hard    1st Round        3         Fromberg R.       Woodbridge T.
# ...       ...          ...      ...                 ...                 ...
# 66676    Hard  Round Robin        3           Sinner J.          Shelton B.
# 66677    Hard  Round Robin        3           Zverev A.  Auger-Aliassime F.
# 66678    Hard   Semifinals        3           Sinner J.        De Minaur A.
# 66679    Hard   Semifinals        3  Auger-Aliassime F.          Alcaraz C.
# 66680    Hard    The Final        3           Sinner J.          Alcaraz C.
#
#                    Winner  ...  Rank_2  Pts_1  Pts_2  Odd_1  Odd_2  \
# 0              Dosedel S.  ...      77     -1     -1  -1.00  -1.00
# 1              Enqvist T.  ...       5     -1     -1  -1.00  -1.00
# 2               Escude N.  ...     655     -1     -1  -1.00  -1.00
# 3              Federer R.  ...      65     -1     -1  -1.00  -1.00
# 4             Fromberg R.  ...     198     -1     -1  -1.00  -1.00
# ...                   ...  ...     ...    ...    ...    ...    ...
# 66676           Sinner J.  ...       5  10000   3970   1.05  10.00
# 66677  Auger-Aliassime F.  ...       8   4960   3845   4.50   1.20
# 66678           Sinner J.  ...       7  10000   3935   1.05  10.00
# 66679          Alcaraz C.  ...       1   3845  11050   4.50   1.20
# 66680           Sinner J.  ...       1  10000  11050   1.50   2.63
#
#              Score player1_win  year  month  day
# 0          6-4 6-2           1  2000      1    3
# 1          3-6 3-6           0  2000      1    3
# 2      6-7 7-5 6-3           1  2000      1    3
# 3          1-6 4-6           0  2000      1    3
# 4      7-6 5-7 6-4           1  2000      1    3
# ...            ...         ...   ...    ...  ...
# 66676      6-3 7-6           1  2025     11   14
# 66677      4-6 6-7           0  2025     11   14
# 66678      7-5 6-2           1  2025     11   15
# 66679      2-6 4-6           0  2025     11   15
# 66680      7-6 7-5           1  2025     11   16
#
# [66681 rows x 21 columns]
